# %%
from queer.arpes import arpes_mesh,arpes_mesh_plot,k_array

# %%
light_energy = 21.2
binding_energy = 3
V0 = 10
N = 200
factor = 4

# %%
x,y,z =arpes_mesh(light_energy,binding_energy,V0,N,factor)
# Out:
# /home/susy/Projects/queer/queer/arpes.py:32: RuntimeWarning: invalid value encountered in sqrt
#   kz = np.sqrt(C * (Ek + V0) - kx**2 - ky**2)

# %%
arpes_mesh_plot(light_energy,binding_energy,V0,N,factor)

# %%
binding_array = np.arange(0.2,3.1,0.2)

# %%
len(binding_array)
# Out:
# 15

# %%
binding_array
# Out:
# array([0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6,
#        2.8, 3. ])

# %%
kmesh_dict = k_array(light_energy,binding_array,V0,N,factor)
# Out:
# /home/susy/Projects/queer/queer/arpes.py:32: RuntimeWarning: invalid value encountered in sqrt
#   kz = np.sqrt(C * (Ek + V0) - kx**2 - ky**2)

# %%
kmesh_dict
# Out:
# {np.float64(0.2): (array([-2., -2., -2., ...,  2.,  2.,  2.], shape=(40000,)),
#   array([-2.        , -1.9798995 , -1.95979899, ...,  1.95979899,
#           1.9798995 ,  2.        ], shape=(40000,)),
#   array([0.37080992, 0.46636679, 0.54469065, ..., 0.54469065, 0.46636679,
#          0.37080992], shape=(40000,))),
#  np.float64(0.4): (array([-2., -2., -2., ...,  2.,  2.,  2.], shape=(40000,)),
#   array([-2.        , -1.9798995 , -1.95979899, ...,  1.95979899,
#           1.9798995 ,  2.        ], shape=(40000,)),
#   array([0.29154759, 0.40619943, 0.49415372, ..., 0.49415372, 0.40619943,
#          0.29154759], shape=(40000,))),
#  np.float64(0.6000000000000001): (array([-2., -2., -2., ...,  2.,  2.,  2.], shape=(40000,)),
#   array([-2.        , -1.9798995 , -1.95979899, ...,  1.95979899,
#           1.9798995 ,  2.        ], shape=(40000,)),
#   array([0.18027756, 0.33540719, 0.43782177, ..., 0.43782177, 0.33540719,
#          0.18027756], shape=(40000,))),
# ...
