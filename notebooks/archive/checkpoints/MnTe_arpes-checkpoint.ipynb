# %%
# Import QUEER library
import queer
from queer import *
from queer.utils import path_create

import matplotlib.pyplot as plt
import numpy as np
from queer.mesh import mesh_crystal,mesh_cartesian,cartesian2crystal,crystal2cartesian

# %%
from queer.arpes import arpes_mesh,arpes_mesh_plot,k_array

# %%
"""
Example script for calculating and plotting electronic band structure
along high-symmetry paths in the Brillouin zone.
"""

# Input files
file_path = "./"
nscf = "nscf.out"
# wout = "NbSe2.wout"
hr = "afm1_hr.dat"

# Number of k points along the path

# Energy axis limits
ylim = [-2, 2]

model = queer.model(hr, file_path, nscf,read_ef=True)

# %%
k_points = 800
custom_points = [
    [1/2, 0, 0],   # M
    [0, 0, 0],     # Gamma
    [1/2, 0, 0],   # M
    [1/3, 1/3, 0], # K
    [0, 0, 0],      # Back to Gamma
    [1/3, 1/3, 0] # K
]

# Create the path
corner_points, path = path_create(k_points, custom_points)

# Define symmetry points and labels
sym = corner_points
labels = ['M','Γ', 'M', 'K', 'Γ', 'K']

# %%
    
# Optional: apply a shift to the Fermi energy if needed
# model = queer(file_path, nscf, wout, hr, shift=0.1)

# Calculate band dispersion along the path
print("Calculating band structure...")  
bands = model.calculate_energy(path)

# Plot bands
print("Plotting band structure...")
model.plot_electron_path(
    bands, sym, labels, ylim=[-4,4])

# %%
model.g_vec

# %%
g_vec = model.g_vec

# %%
light_energy = 21.2
V0 = 10
N = 200
factor = 4
binding_array = np.arange(0.5,3.1,0.5)
kmesh_dict = k_array(light_energy,binding_array,V0,N,factor)

# %%
energy_dict = {}
for i,j in kmesh_dict.items():
    kmesh = np.array(j)
    inv_kmesh = crystal2cartesian(kmesh,g_vec)
    band = model.calculate_energy(inv_kmesh)
    energy_dict[i] =band

# %%
mesh_tile_dict = {}
band_tile_dict = {}
for i,j in kmesh_dict.items():
    kmesh = np.array(j)
    tile_mesh = []
    for k in range(energy_dict[i].shape[0]):
        tile_mesh.append(kmesh.T)
    mesh_tile = np.array(tile_mesh).reshape(-1,3)
    mesh_tile_dict[i]=mesh_tile
    band_tile = energy_dict[i].flatten()
    band_tile_dict[i]=band_tile

# %%
df_dict = {}
for i,j in kmesh_dict.items():
    mesh_tile = mesh_tile_dict[i]
    band_tile = band_tile_dict[i]
    df = pd.DataFrame()
    df['kx']=mesh_tile.T[0]
    df['ky']=mesh_tile.T[1]
    df['kz']=mesh_tile.T[2]
    df['e']=band_tile
    df_dict[i]=df

# %%
df_dict[0.5]

# %%
for i,j in df_dict.items(): 
    query = j.query(f"{i}-0.01<e<{i}+0.01")
    plt.scatter(query.kx,query.ky,s=1)
    plt.axis("equal")
    # plt.xlim(-2,2)
    # plt.ylim(-2,2)
    plt.title(f"Binding Energy = {i}")
    plot_hexagon_from_inner_radius(1.74529598/2)
    plt.show()

# %%
def plot_hexagon_from_inner_radius(inner_radius):
    # For a regular hexagon, the outer radius (vertex to center) is:
    # outer_radius = inner_radius / cos(30°)
    outer_radius = inner_radius / np.cos(math.pi/6)
    
    # Generate points for hexagon (6 vertices)
    angles = np.linspace(0, 2*np.pi, 7)[:-1]  # 6 evenly spaced angles
    x_vertices = outer_radius * np.cos(angles)
    y_vertices = outer_radius * np.sin(angles)
    
    # Close the shape by repeating the first point
    x_vertices = np.append(x_vertices, x_vertices[0])
    y_vertices = np.append(y_vertices, y_vertices[0])
    
    # Create the plot
    # plt.figure(figsize=(8, 8))
    
    # Plot the hexagon
    plt.plot(x_vertices, y_vertices, 'b-', linewidth=2)
    plt.scatter(0,0)

# %%
inner_radius = 5  # Change this to your desired inner radius
plot_hexagon_from_inner_radius(1.74529598)

# %%
def plot_hexagon_from_inner_radius(inner_radius):
    # For a regular hexagon, the outer radius (vertex to center) is:
    # outer_radius = inner_radius / cos(30°)
    outer_radius = inner_radius / np.cos(math.pi/6)
    
    # Generate points for hexagon (6 vertices)
    angles = np.linspace(0, 2*np.pi, 7)[:-1]  # 6 evenly spaced angles
    x_vertices = outer_radius * np.cos(angles)
    y_vertices = outer_radius * np.sin(angles)
    
    # Close the shape by repeating the first point
    x_vertices = np.append(x_vertices, x_vertices[0])
    y_vertices = np.append(y_vertices, y_vertices[0])
    
    # Create the plot
    plt.figure(figsize=(8, 8))
    
    # Plot the hexagon
    plt.plot(x_vertices, y_vertices, 'b-', linewidth=2)
    

    
    # Plot the center point
    plt.plot(0, 0, 'ko', markersize=5)
    
    # Set equal aspect ratio
    plt.axis('equal')
    
    # Add grid, labels, and legend
    plt.grid(True)
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.title(f'Regular Hexagon with Inner Circle Radius = {inner_radius}')
    plt.legend()
    


# Example usage
inner_radius = 5  # Change this to your desired inner radius
plot_hexagon_from_inner_radius(inner_radius)

# %%
df_dict[0.5]

# %%
for i,j in energy_dict.items():
    print(j.shape[0])

# %%
`12345energy_dict[0.90-].shape[0]

# %%
tile_mesh=[]
for i in range(bands_mesh.shape[0]):
    tile_mesh.append(mesh_3d)

# %%
mesh_tile = np.array(tile_mesh).reshape(-1,3)

# %%
band_tile = bands_mesh.flatten()

# %%
df = pd.DataFrame()
df['kx']=mesh_tile.T[0]
df['ky']=mesh_tile.T[1]
df['kz']=mesh_tile.T[2]
df['x']=t_mesh.T[0]
df['y']=t_mesh.T[1]
df['z']=t_mesh.T[2]
df['e']=band_tile

# %%
energy_dict[0.5]

# %%
energy_dict = {}
for i,j in kmesh_dict.items():
    kmesh = np.array(j)
    # print(kmesh)
    inv_kmesh = crystal2cartesian(kmesh,g_vec)
    band = model.calculate_energy(inv_kmesh)
    energy_dict[i] =band
    # queer.plots.plot_electron_mesh(band=band,mesh=kmesh,metallic_band_index=6)
    # print(inv_kmesh)

# %%
mesh_3d = mesh_cartesian([150,150,50],factor=2)

# %%
bands_mesh = model.calculate_energy(mesh_3d)

# %%
tile_mesh=[]
for i in range(bands_mesh.shape[0]):
    tile_mesh.append(mesh_3d)

# %%
mesh_tile = np.array(tile_mesh).reshape(-1,3)

# %%
band_tile = bands_mesh.flatten()

# %%
g_vec = np.array([[1.5114710872,0.8726482391,0.0000000000],[0.0000000000,1.7452964781,0.0000000000],[0.0000000000,0.0000000000,0.9362517269]])

# %%
t_mesh = np.dot(g_vec.T, mesh_tile.T).T

# %%
t_mesh

# %%
mesh_tile

# %%
df = pd.DataFrame()
df['kx']=mesh_tile.T[0]
df['ky']=mesh_tile.T[1]
df['kz']=mesh_tile.T[2]
df['x']=t_mesh.T[0]
df['y']=t_mesh.T[1]
df['z']=t_mesh.T[2]
df['e']=band_tile

# %%
df_copy = df.copy()

# %%
df_copy = df_copy.query("-5<e<0")

# %%
df_copy['e'] = df_copy['e'] - df_copy['e'].max()

# %%
df_copy.to_csv('limit_shift_scan.dat', float_format='%.3f', sep='\t',index=False)

# %%
df_copy[['x', 'y', 'z', 'e']].to_csv('xyze.dat', float_format='%.3f', sep='\t',index=False)

# %%
df_copy.describe()

# %%
df_copy.

# %%
df_copy.query("-5<e<0").describe()

# %%
df_copy

# %%
plt.scatter(df_copy.query("0.49<=ky<=0.5").query("0.0<=kx<=0.01").z,df_copy.query("0.49<=ky<=0.5").query("0.0<=kx<=0.01").e)
plt.xlim(0,1)
plt.ylim(-3,0)

# %%
df_copy[:100]

# %%
df.query("-5<e<0").to_csv('df_z_limit.dat', float_format='%.3f', sep='\t',index=False)

# %%
df

# %%
df.to_csv('z_scan.dat', float_format='%.3f', sep='\t',index=False)

# %%
`1234567`

# %%
df

# %%
lim_1 = df.query('-1<e<1 ')

# %%
plt.scatter(lim_1.x,lim_1.y,c=lim_1.e,cmap='jet',s=4)
plt.axis("equal")
plt.colorbar()
plt.show()

# %%
mesh_3d_z = mesh_3d+[0,0,0.31]

# %%
bands_mesh_z = model.calculate_energy(mesh_3d_z)

# %%
tile_mesh_z=[]
for i in range(bands_mesh_z.shape[0]):
    tile_mesh_z.append(mesh_3d_z)

# %%
mesh_tile_z = np.array(tile_mesh_z).reshape(-1,3)

# %%
band_tile_z = bands_mesh_z.flatten()

# %%
g_vec = np.array([[1.5114710872,0.8726482391,0.0000000000],[0.0000000000,1.7452964781,0.0000000000],[0.0000000000,0.0000000000,0.9362517269]])
t_mesh_z = np.dot(g_vec.T, mesh_tile_z.T).T

# %%
df_z = pd.DataFrame()
df_z['kx']=mesh_tile_z.T[0]
df_z['ky']=mesh_tile_z.T[1]
df_z['kz']=mesh_tile_z.T[2]
df_z['x']=t_mesh_z.T[0]
df_z['y']=t_mesh_z.T[1]
df_z['z']=t_mesh_z.T[2]
df_z['e']=band_tile_z

# %%
steps = np.arange(-2,0,0.05)

# %%
df_z.to_csv('0.3_inverse.dat', sep='\t')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_z = pd.read_csv('0.3_inverse.dat', sep='\t')

# %%
steps = np.arange(-4,0,0.1)

# %%
for i in steps:
    plus = i +0.02
    minus = i - 0.02
    lim_1_z = df_z.query(f'{minus}<e<{plus}')
    plt.scatter(lim_1_z.x,lim_1_z.y,s=1)
    plt.axis("equal")
    plt.title(rf"$\delta_{{Fermi}}$={np.around(i,3)} $k_{{z}}$=0.3 $\AA^{{-1}}$")
    plt.tight_layout()
    plt.savefig(f'./figs/{np.around(i,2)}.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
for i in :
    # lim_1_z = df_z.query(f'-1.<e< ')
    # plt.scatter(lim_1_z.x,lim_1_z.y,c=lim_1_z.e,cmap='jet',s=4)
    # plt.axis("equal")
    # plt.colorbar()
    # plt.show()
