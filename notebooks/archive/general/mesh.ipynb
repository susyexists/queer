# %%
# Import QUEER library
import queer
from queer import *
from queer.utils import path_create

import matplotlib.pyplot as plt
import numpy as np

# %%
def mesh_crystal(N,dimension = 3,factor=1):
    mesh = mesh_cartesian(N, factor=factor)
    t_mesh = np.dot(g_vec.T, mesh.T)
    return t_mesh

# %%
mesh_crystal([50,50,1],factor=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 mesh_crystal([50,50,1],factor=2)
#
# Cell In[3], line 3, in mesh_crystal(N, dimension, factor)
#       1 def mesh_crystal(N,dimension = 3,factor=1):
#       2     mesh = mesh_cartesian(N, factor=factor)
# ----> 3     t_mesh = np.dot(g_vec.T, mesh.T)
#       4     return t_mesh
#
# NameError: name 'g_vec' is not defined
